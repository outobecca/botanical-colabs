# %%
# Mobile Plant Card Generator
# Run with: mercury run mobile_plant_card.ipynb

import mercury as mr
import requests
from IPython.display import HTML

# Create mobile-optimized app
app = mr.App(
    title="🌱 Plant Card Generator",
    description="Create plant care cards on mobile",
    show_code=False,
    show_prompt=False
)

# Mobile-friendly inputs
plant_name = mr.Text(
    value="",
    label="Plant Name",
    placeholder="e.g., Tomato, Rose, Basil",
    size="large"
)

generate_btn = mr.Button(
    label="Generate Plant Card",
    variant="primary",
    size="large"
)

# Mobile-optimized layout
mr.Markdown("""
## 🌿 Botanical Plant Card Generator

Enter a plant name above and tap Generate to create a mobile-friendly plant care card!
""")

# %%
def create_mobile_plant_card(plant_name):
    """Generate mobile-optimized plant card"""
    
    # Sample data (replace with real API calls)
    plant_data = {
        'name': plant_name.title(),
        'scientific_name': f'{plant_name} spp.',
        'family': 'Solanaceae',
        'light': 'Full sun (6+ hours)',
        'water': 'Regular watering',
        'soil': 'Well-draining, fertile',
        'temperature': '65-85°F (18-29°C)',
        'fertilizer': 'Monthly during growing season',
        'pests': 'Watch for aphids, spider mites',
        'tips': 'Pinch flowers for bushier growth'
    }
    
    # Mobile-responsive HTML card
    card_html = f"""
    <div style="
        max-width: 100%;
        margin: 10px auto;
        border-radius: 12px;
        box-shadow: 0 2px 8px rgba(0,0,0,0.1);
        background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
        font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
    ">
        <div style="padding: 20px; text-align: center;">
            <h2 style="margin: 0; color: #2c3e50; font-size: 1.5em;">
                🌱 {plant_data['name']}
            </h2>
            <p style="margin: 5px 0; color: #7f8c8d; font-style: italic;">
                {plant_data['scientific_name']}
            </p>
        </div>
        
        <div style="padding: 0 20px 20px;">
            <div style="display: grid; gap: 12px;">
                <div style="background: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; border-left: 4px solid #27ae60;">
                    <strong>☀️ Light:</strong> {plant_data['light']}
                </div>
                <div style="background: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; border-left: 4px solid #3498db;">
                    <strong>💧 Water:</strong> {plant_data['water']}
                </div>
                <div style="background: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; border-left: 4px solid #8e44ad;">
                    <strong>🌱 Soil:</strong> {plant_data['soil']}
                </div>
                <div style="background: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; border-left: 4px solid #e74c3c;">
                    <strong>🌡️ Temperature:</strong> {plant_data['temperature']}
                </div>
                <div style="background: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; border-left: 4px solid #f39c12;">
                    <strong>🧪 Fertilizer:</strong> {plant_data['fertilizer']}
                </div>
                <div style="background: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; border-left: 4px solid #9b59b6;">
                    <strong>🐛 Pests:</strong> {plant_data['pests']}
                </div>
                <div style="background: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; border-left: 4px solid #1abc9c;">
                    <strong>💡 Tip:</strong> {plant_data['tips']}
                </div>
            </div>
        </div>
    </div>
    """
    
    return card_html

# Generate card when button clicked
if generate_btn.clicked and plant_name.value.strip():
    card_html = create_mobile_plant_card(plant_name.value.strip())
    mr.HTML(card_html)
elif generate_btn.clicked:
    mr.Markdown("*Please enter a plant name first!* 📝")
